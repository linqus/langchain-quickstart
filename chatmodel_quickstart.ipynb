# %% [markdown]
# # Setup

# %%
# %pip install langchain-openai
# Out:
# Requirement already satisfied: langchain-openai in c:\users\karol\anaconda3\envs\langchain\lib\site-packages (0.0.6)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: langchain-core<0.2,>=0.1.16 in c:\users\karol\anaconda3\envs\langchain\lib\site-packages (from langchain-openai) (0.1.22)
# Requirement already satisfied: numpy<2,>=1 in c:\users\karol\anaconda3\envs\langchain\lib\site-packages (from langchain-openai) (1.26.4)
# Requirement already satisfied: openai<2.0.0,>=1.10.0 in c:\users\karol\anaconda3\envs\langchain\lib\site-packages (from langchain-openai) (1.12.0)
# Requirement already satisfied: tiktoken<1,>=0.5.2 in c:\users\karol\anaconda3\envs\langchain\lib\site-packages (from langchain-openai) (0.6.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\karol\anaconda3\envs\langchain\lib\site-packages (from langchain-core<0.2,>=0.1.16->langchain-openai) (6.0.1)
# Requirement already satisfied: anyio<5,>=3 in c:\users\karol\anaconda3\envs\langchain\lib\site-packages (from langchain-core<0.2,>=0.1.16->langchain-openai) (4.2.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\karol\anaconda3\envs\langchain\lib\site-packages (from langchain-core<0.2,>=0.1.16->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<0.0.88,>=0.0.87 in c:\users\karol\anaconda3\envs\langchain\lib\site-packages (from langchain-core<0.2,>=0.1.16->langchain-openai) (0.0.87)
# Requirement already satisfied: packaging<24.0,>=23.2 in c:\users\karol\anaconda3\envs\langchain\lib\site-packages (from langchain-core<0.2,>=0.1.16->langchain-openai) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\karol\anaconda3\envs\langchain\lib\site-packages (from langchain-core<0.2,>=0.1.16->langchain-openai) (1.10.14)
# Requirement already satisfied: requests<3,>=2 in c:\users\karol\anaconda3\envs\langchain\lib\site-packages (from langchain-core<0.2,>=0.1.16->langchain-openai) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\karol\anaconda3\envs\langchain\lib\site-packages (from langchain-core<0.2,>=0.1.16->langchain-openai) (8.2.3)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\karol\anaconda3\envs\langchain\lib\site-packages (from openai<2.0.0,>=1.10.0->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\karol\anaconda3\envs\langchain\lib\site-packages (from openai<2.0.0,>=1.10.0->langchain-openai) (0.26.0)
# Requirement already satisfied: sniffio in c:\users\karol\anaconda3\envs\langchain\lib\site-packages (from openai<2.0.0,>=1.10.0->langchain-openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\karol\anaconda3\envs\langchain\lib\site-packages (from openai<2.0.0,>=1.10.0->langchain-openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\karol\anaconda3\envs\langchain\lib\site-packages (from openai<2.0.0,>=1.10.0->langchain-openai) (4.9.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\karol\anaconda3\envs\langchain\lib\site-packages (from tiktoken<1,>=0.5.2->langchain-openai) (2023.12.25)
# Requirement already satisfied: idna>=2.8 in c:\users\karol\anaconda3\envs\langchain\lib\site-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.16->langchain-openai) (3.6)
# Requirement already satisfied: certifi in c:\users\karol\anaconda3\envs\langchain\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.10.0->langchain-openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\karol\anaconda3\envs\langchain\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.10.0->langchain-openai) (1.0.3)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\karol\anaconda3\envs\langchain\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.10.0->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\karol\anaconda3\envs\langchain\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.2,>=0.1.16->langchain-openai) (2.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\karol\anaconda3\envs\langchain\lib\site-packages (from requests<3,>=2->langchain-core<0.2,>=0.1.16->langchain-openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\karol\anaconda3\envs\langchain\lib\site-packages (from requests<3,>=2->langchain-core<0.2,>=0.1.16->langchain-openai) (2.2.0)
# Requirement already satisfied: colorama in c:\users\karol\anaconda3\envs\langchain\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.10.0->langchain-openai) (0.4.6)

# %% [markdown]
# ``` bash
# export OPENAI_API_KEY="..."

# %% [markdown]
# ---

# %% [markdown]
# ```python
# from langchain_openai import ChatOpenAI
#
# chat = ChatOpenAI(openai_api_key="...")

# %% [markdown]
# ---

# %%
from langchain_openai import ChatOpenAI

chat = ChatOpenAI()

# %% [markdown]
# # LCEL

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage(content="You're a helpful assistant"),
    HumanMessage(content="What is the purpose of model regularization?"),
]

# %%
chat.invoke(messages)
# Out:
# AIMessage(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, including the noise and outliers, which can lead to poor generalization on unseen data. Regularization techniques add a penalty term to the model's loss function, discouraging overly complex models and promoting simpler models that are more likely to generalize well. This helps to improve the model's performance on new, unseen data by reducing variance and increasing bias. Common regularization techniques include L1 and L2 regularization, dropout, and early stopping.")

# %%
for chunk in chat.stream(messages):
    print(chunk.content, end="", flush=True)
# Out:
# The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the noise in the training data rather than the underlying pattern, leading to poor generalization performance on unseen data. Regularization techniques add a penalty term to the model's loss function to discourage overly complex models that are too sensitive to the training data. This helps to improve the model's ability to generalize well to new, unseen data by promoting simpler and more robust models. Common regularization techniques include L1 and L2 regularization, dropout, and early stopping.

# %%
chat.batch([messages])
# Out:
# [AIMessage(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques help to simplify the model by penalizing overly complex or large coefficients, which can help improve the model's generalization ability and performance on unseen data. By adding regularization terms to the model's loss function, we can control the model complexity and reduce the risk of overfitting. Common regularization techniques include L1 regularization (Lasso), L2 regularization (Ridge), and Elastic Net regularization.")]

# %%
await chat.ainvoke(messages)
# Out:
# AIMessage(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the noise and randomness in the training data rather than the underlying pattern, which can result in poor performance when applied to new, unseen data.\n\nRegularization techniques add a penalty term to the model's loss function, discouraging overly complex models that may be prone to overfitting. By penalizing large coefficients or adding constraints to the model complexity, regularization helps to generalize the model and improve its performance on unseen data. Common regularization techniques include L1 regularization (Lasso), L2 regularization (Ridge), and Elastic Net regularization.")

# %%
async for chunk in chat.astream(messages):
    print(chunk.content, end="", flush=True)
# Out:
# The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point where it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, which helps to control the complexity of the model and prevent it from fitting noise in the training data. This can improve the model's generalization performance and make it more robust when making predictions on new data. Common regularization techniques include L1 regularization (Lasso), L2 regularization (Ridge), and dropout regularization.

# %%
async for chunk in chat.astream_log(messages):
    print(chunk)
# Out:
# RunLogPatch({'op': 'replace',
#   'path': '',
#   'value': {'final_output': None,
#             'id': '5f0adcf4-f7ed-47c2-a586-be478bca361a',
#             'logs': {},
#             'name': 'ChatOpenAI',
#             'streamed_output': [],
#             'type': 'llm'}})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='The')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' purpose')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' of')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' model')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' regularization')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' is')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' to')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' prevent')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' over')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent over')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='fit')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfit')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='ting')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' in')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' machine')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' learning')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' models')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='.')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models.')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' Over')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Over')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='fit')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfit')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='ting')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' occurs')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' when')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' a')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' model')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' learns')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' the')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' training')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' data')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' too')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' well')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=',')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well,')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' to')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' the')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' point')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' that')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' it')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' also')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' learns')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' the')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' noise')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' in')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' the')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' data')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=',')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data,')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' resulting')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' in')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' poor')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' general')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor general')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='ization')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' to')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' new')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=',')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new,')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' unseen')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' data')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='.')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data.')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' Regular')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regular')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='ization')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' techniques')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' help')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' to')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' reduce')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' over')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce over')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='fit')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfit')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='ting')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' by')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' adding')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' a')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' penalty')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' term')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' to')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' the')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' model')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content="'s")},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' objective')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' function')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=',')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function,")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' which')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' discour')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discour")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='ages')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' overly')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' complex')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' models')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' and')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' encourages')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' simpler')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' models')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' that')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' generalize')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that generalize")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' better')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that generalize better")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' to')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that generalize better to")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' new')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that generalize better to new")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' data')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that generalize better to new data")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='.')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that generalize better to new data.")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' Regular')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that generalize better to new data. Regular")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='ization')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that generalize better to new data. Regularization")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' techniques')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that generalize better to new data. Regularization techniques")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' include')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that generalize better to new data. Regularization techniques include")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' L')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that generalize better to new data. Regularization techniques include L")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='1')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that generalize better to new data. Regularization techniques include L1")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' regularization')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that generalize better to new data. Regularization techniques include L1 regularization")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' (')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that generalize better to new data. Regularization techniques include L1 regularization (")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='L')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that generalize better to new data. Regularization techniques include L1 regularization (L")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='asso')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that generalize better to new data. Regularization techniques include L1 regularization (Lasso")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='),')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that generalize better to new data. Regularization techniques include L1 regularization (Lasso),")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' L')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that generalize better to new data. Regularization techniques include L1 regularization (Lasso), L")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='2')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that generalize better to new data. Regularization techniques include L1 regularization (Lasso), L2")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' regularization')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that generalize better to new data. Regularization techniques include L1 regularization (Lasso), L2 regularization")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' (')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that generalize better to new data. Regularization techniques include L1 regularization (Lasso), L2 regularization (")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='R')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that generalize better to new data. Regularization techniques include L1 regularization (Lasso), L2 regularization (R")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='idge')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that generalize better to new data. Regularization techniques include L1 regularization (Lasso), L2 regularization (Ridge")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='),')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that generalize better to new data. Regularization techniques include L1 regularization (Lasso), L2 regularization (Ridge),")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' and')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that generalize better to new data. Regularization techniques include L1 regularization (Lasso), L2 regularization (Ridge), and")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' elastic')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that generalize better to new data. Regularization techniques include L1 regularization (Lasso), L2 regularization (Ridge), and elastic")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' net')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that generalize better to new data. Regularization techniques include L1 regularization (Lasso), L2 regularization (Ridge), and elastic net")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' regularization')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that generalize better to new data. Regularization techniques include L1 regularization (Lasso), L2 regularization (Ridge), and elastic net regularization")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=',')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that generalize better to new data. Regularization techniques include L1 regularization (Lasso), L2 regularization (Ridge), and elastic net regularization,")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' among')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that generalize better to new data. Regularization techniques include L1 regularization (Lasso), L2 regularization (Ridge), and elastic net regularization, among")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' others')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that generalize better to new data. Regularization techniques include L1 regularization (Lasso), L2 regularization (Ridge), and elastic net regularization, among others")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='.')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it also learns the noise in the data, resulting in poor generalization to new, unseen data. Regularization techniques help to reduce overfitting by adding a penalty term to the model's objective function, which discourages overly complex models and encourages simpler models that generalize better to new data. Regularization techniques include L1 regularization (Lasso), L2 regularization (Ridge), and elastic net regularization, among others.")})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='')})

# %% [markdown]
# # \_\_call\_\_

# %%
from langchain.schema import HumanMessage, SystemMessage

chat(
    [
        HumanMessage(
            content="Translate this sentence from English to French: I love programming."
        )
    ]
)
# Out:
# c:\Users\karol\anaconda3\envs\langchain\Lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The function `__call__` was deprecated in LangChain 0.1.7 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# AIMessage(content="J'adore programmer.")

# %%
messages = [
    SystemMessage(
        content="You are a helpful assistant that translates English to French."
    ),
    HumanMessage(content="I love programming."),
]
chat(messages)
# Out:
# AIMessage(content="J'adore la programmation.")

# %% [markdown]
# # `generate`

# %%
batch_messages = [
    [
        SystemMessage(
            content="You are a helpful assistant that translates English to French."
        ),
        HumanMessage(content="I love programming."),
    ],
    [
        SystemMessage(
            content="You are a helpful assistant that translates English to French."
        ),
        HumanMessage(content="I love artificial intelligence."),
    ],
]
result = chat.generate(batch_messages)
result
# Out:
# LLMResult(generations=[[ChatGeneration(text="J'adore la programmation.", generation_info={'finish_reason': 'stop', 'logprobs': None}, message=AIMessage(content="J'adore la programmation."))], [ChatGeneration(text="J'adore l'intelligence artificielle.", generation_info={'finish_reason': 'stop', 'logprobs': None}, message=AIMessage(content="J'adore l'intelligence artificielle."))]], llm_output={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 53, 'total_tokens': 73}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': 'fp_69829325d0'}, run=[RunInfo(run_id=UUID('0bb077a3-f964-4b6b-b55b-da9a145a78ef')), RunInfo(run_id=UUID('91d3c582-a48b-48ea-8994-8e682dc369c2'))])

# %%
result.llm_output
# Out:
# {'token_usage': {'completion_tokens': 20,
#   'prompt_tokens': 53,
#   'total_tokens': 73},
#  'model_name': 'gpt-3.5-turbo',
#  'system_fingerprint': 'fp_69829325d0'}
